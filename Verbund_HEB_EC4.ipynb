# %% [markdown]
# # **Verbundstütze nach EC4**

# %% [markdown]
# ### Step 1:
# Append the directory containing your .py file to the system path and import the module

# %%
import sys
sys.path.append('/Users/descalante/pycode/eng_module')
import columns as col

# %% [markdown]
# ### Step 3: Define the inputs for the function
#
# #### Generates a P-M Diagram for a HEB-Profile Steel-Concrete composite column according to the EC4.
#
# #### Parameters:
#     L (float): Column length in m.
#     b (float): Column width in mm.
#     h (float): Column height in mm.
#     A_st (float): H-Profile cross section in cm².
#     I_st (float): H-Profile Inertia along Y-Y axis in cm⁴.
#     As_b (float): Reinforcement cross section in cm².
#     I_by (float): Reinforcement inertia in cm⁴.
#     fy (int): Steel nominal yield strength in MPa.
#     fc (int): Concrete nominal compressive strength in MPa.
#     fs (int): Reinforcement steel nominal yield strength in MPa. Defaults to 500 MPa.
#     Ec (int, optional): Concrete E-Module in GPa. Defaults to 34 GPa.
#     Es (int, optional): Steel E-Module in GPa. Defaults to 200 GPa and 210 GPa for  reinforcement.

# %%
L = 4 # in m
b = 260 # in mm
h = 260 # in mm
A_st = 118.4 # in cm²
I_st = 5130 # in cm⁴
As_b = 12.56 # in cm²
I_by = 706 # in cm⁴
fy = 355 # in MPa
fc = 35 # in MPa

# %% [markdown]
# ### Step 4:
# Run the function and generate the P-M plot

# %%
col.composite_HE_ec4(L, b, h, A_st, I_st, As_b, I_by, fy, fc)
# Out:
# N_cr= 8765.99 kN
# N_pl_rd= 5830.28 kN
# M_max_rd= 503.31 kNm
# M_pl_rd= 498.20 kNm
